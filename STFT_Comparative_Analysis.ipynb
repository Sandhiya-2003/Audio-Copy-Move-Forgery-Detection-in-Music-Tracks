# %% [markdown]
# # ***Mount Drive***

# %%
from google.colab import drive
drive.mount("/content/drive", force_remount=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# # ***STFT Spectrogram Generation***

# %%
import os
import numpy as np
import librosa
import matplotlib.pyplot as plt
import gc

# %%
def process_audio_to_spectrograms(audio_folder, image_output_folder, npy_output_folder, sr, n_fft, hop_length):
    # Disable interactive plotting
    plt.ioff()

    # Get all .wav files
    all_files = [f for f in os.listdir(audio_folder) if f.endswith(".wav")]
    print(f"Found {len(all_files)} WAV files to process...")

    # Process each file
    for file_idx, file in enumerate(all_files):
        try:
            file_path = os.path.join(audio_folder, file)
            base_filename = os.path.splitext(file)[0]

            # Load audio
            y, _ = librosa.load(file_path, sr=sr)

            # STFT and log scale
            stft_result = librosa.stft(y, n_fft=n_fft, hop_length=hop_length)
            stft_magnitude = np.abs(stft_result)
            log_stft = librosa.amplitude_to_db(stft_magnitude, ref=np.max)

            # Save .npy
            npy_filename = os.path.join(npy_output_folder, f"{base_filename}.npy")
            np.save(npy_filename, log_stft)

            # Save spectrogram image
            plt.figure(figsize=(10, 5))
            librosa.display.specshow(log_stft, sr=sr, hop_length=hop_length, x_axis="time", y_axis="log")
            plt.colorbar(label="dB")
            plt.title("STFT Spectrogram")
            image_filename = os.path.join(image_output_folder, f"{base_filename}_spectrogram_image.png")
            plt.savefig(image_filename, dpi=150, bbox_inches='tight', pad_inches=0.1)
            plt.close('all')

            gc.collect()

            print(f"[{file_idx + 1}/{len(all_files)}] Processed: {base_filename}")

        except Exception as e:
            print(f"Error processing {file}: {e}")

    gc.collect()

# %% [markdown]
# ### ***STFT for Original Tracks***

# %% [markdown]
# ***Classical***

# %%
audio_folder = "/content/drive/MyDrive/preprocessed_wav_tracks/classical"
image_output_folder = "/content/drive/MyDrive/STFT_Spectrograms/original/images"
npy_output_folder = "/content/drive/MyDrive/STFT_Spectrograms/original/npy_files"
sr = 16000
hop_length = 512
n_fft = 1024

process_audio_to_spectrograms(audio_folder, image_output_folder, npy_output_folder, sr, n_fft, hop_length)
# Out:
# Found 250 WAV files to process...
# [1/250] Processed: cl201
# [2/250] Processed: cl202
# [3/250] Processed: cl203
# [4/250] Processed: cl204
# [5/250] Processed: cl205
# [6/250] Processed: cl206
# [7/250] Processed: cl207
# [8/250] Processed: cl208
# [9/250] Processed: cl209
# [10/250] Processed: cl210
# [11/250] Processed: cl211
# [12/250] Processed: cl212
# [13/250] Processed: cl213
# [14/250] Processed: cl214
# [15/250] Processed: cl215
# [16/250] Processed: cl216
# [17/250] Processed: cl217
# [18/250] Processed: cl218
# [19/250] Processed: cl219
# [20/250] Processed: cl220
# [21/250] Processed: cl221
# [22/250] Processed: cl222
# [23/250] Processed: cl223
# [24/250] Processed: cl224
# [25/250] Processed: cl225
# [26/250] Processed: cl226
# [27/250] Processed: cl227
# [28/250] Processed: cl228
# [29/250] Processed: cl229
# [30/250] Processed: cl230
# [31/250] Processed: cl231
# [32/250] Processed: cl232
# [33/250] Processed: cl233
# [34/250] Processed: cl234
# ...

# %% [markdown]
# ***Country***

# %%
audio_folder = "/content/drive/MyDrive/preprocessed_wav_tracks/country"
image_output_folder = "/content/drive/MyDrive/STFT_Spectrograms/original/images"
npy_output_folder = "/content/drive/MyDrive/STFT_Spectrograms/original/npy_files"
sr = 16000
hop_length = 512
n_fft = 1024

process_audio_to_spectrograms(audio_folder, image_output_folder, npy_output_folder, sr, n_fft, hop_length)
# Out:
# Found 250 WAV files to process...
# [1/250] Processed: c201
# [2/250] Processed: c202
# [3/250] Processed: c203
# [4/250] Processed: c204
# [5/250] Processed: c205
# [6/250] Processed: c206
# [7/250] Processed: c207
# [8/250] Processed: c208
# [9/250] Processed: c209
# [10/250] Processed: c210
# [11/250] Processed: c211
# [12/250] Processed: c212
# [13/250] Processed: c213
# [14/250] Processed: c214
# [15/250] Processed: c215
# [16/250] Processed: c216
# [17/250] Processed: c217
# [18/250] Processed: c218
# [19/250] Processed: c219
# [20/250] Processed: c220
# [21/250] Processed: c221
# [22/250] Processed: c222
# [23/250] Processed: c223
# [24/250] Processed: c224
# [25/250] Processed: c225
# [26/250] Processed: c226
# [27/250] Processed: c227
# [28/250] Processed: c228
# [29/250] Processed: c229
# [30/250] Processed: c230
# [31/250] Processed: c231
# [32/250] Processed: c232
# [33/250] Processed: c233
# [34/250] Processed: c234
# [35/250] Processed: c235
# [36/250] Processed: c236
# ...

# %% [markdown]
# ***Electronic***

# %%
audio_folder = "/content/drive/MyDrive/preprocessed_wav_tracks
forged_tracks"
image_output_folder = "/content/drive/MyDrive/STFT_Spectrograms/forged/images"
npy_output_folder = "/content/drive/MyDrive/STFT_Spectrograms/forged/npy_files"
sr = 16000
hop_length = 512
n_fft = 1024

process_audio_to_spectrograms(audio_folder, image_output_folder, npy_output_folder, sr, n_fft, hop_length)
# Out:
# Found 250 WAV files to process...
# [1/250] Processed: f213_forged
# [2/250] Processed: o171_forged
# [3/250] Processed: h144_forged
# [4/250] Processed: o213_forged
# [5/250] Processed: e012_forged
# [6/250] Processed: c033_forged
# [7/250] Processed: cl039_forged
# [8/250] Processed: h167_forged
# [9/250] Processed: e150_forged
# [10/250] Processed: cl144_forged
# [11/250] Processed: r047_forged
# [12/250] Processed: s189_forged
# [13/250] Processed: o106_forged
# [14/250] Processed: s168_forged
# [15/250] Processed: c047_forged
# [16/250] Processed: r065_forged
# [17/250] Processed: s212_forged
# [18/250] Processed: o150_forged
# [19/250] Processed: h142_forged
# [20/250] Processed: s059_forged
# [21/250] Processed: s154_forged
# [22/250] Processed: f241_forged
# [23/250] Processed: c115_forged
# [24/250] Processed: j033_forged
# [25/250] Processed: cl065_forged
# [26/250] Processed: o057_forged
# [27/250] Processed: e206_forged
# [28/250] Processed: h189_forged
# ...

# %% [markdown]
# ***Low Bitrate MP3 Compression***

# %%
audio_folder = "/content/drive/MyDrive/forged_tracks/low_bitrate_mp3_compression_forged_tracks"
image_output_folder = "/content/drive/MyDrive/STFT_Spectrograms/forged/images"
npy_output_folder = "/content/drive/MyDrive/STFT_Spectrograms/forged/npy_files"
sr = 16000
hop_length = 512
n_fft = 1024

process_audio_to_spectrograms(audio_folder, image_output_folder, npy_output_folder, sr, n_fft, hop_length)
# Out:
# Found 250 WAV files to process...
# [1/250] Processed: p036_forged
# [2/250] Processed: h241_forged
# [3/250] Processed: c150_forged
# [4/250] Processed: c069_forged
# [5/250] Processed: f175_forged
# [6/250] Processed: s150_forged
# [7/250] Processed: o092_forged
# [8/250] Processed: r012_forged
# [9/250] Processed: o047_forged
# [10/250] Processed: r106_forged
# [11/250] Processed: o154_forged
# [12/250] Processed: cl211_forged
# [13/250] Processed: e144_forged
# [14/250] Processed: h069_forged
# [15/250] Processed: h031_forged
# [16/250] Processed: r116_forged
# [17/250] Processed: e098_forged
# [18/250] Processed: s179_forged
# [19/250] Processed: r069_forged
# [20/250] Processed: h235_forged
# [21/250] Processed: e189_forged
# [22/250] Processed: p178_forged
# [23/250] Processed: r057_forged
# [24/250] Processed: h184_forged
# [25/250] Processed: cl241_forged
# [26/250] Processed: h206_forged
# [27/250] Processed: j241_forged
# [28/250] Processed: r085_forged
# ...

# %% [markdown]
# ***Time Stretch + Pitch Shift***

# %%
audio_folder = "/content/drive/MyDrive/forged_tracks/time_stretch_pitch_shift_forged_tracks"
image_output_folder = "/content/drive/MyDrive/STFT_Spectrograms/forged/images"
npy_output_folder = "/content/drive/MyDrive/STFT_Spectrograms/forged/npy_files"
sr = 16000
hop_length = 512
n_fft = 1024

process_audio_to_spectrograms(audio_folder, image_output_folder, npy_output_folder, sr, n_fft, hop_length)
# Out:
# Found 250 WAV files to process...
# [1/250] Processed: j224_forged
# [2/250] Processed: e231_forged
# [3/250] Processed: r022_forged
# [4/250] Processed: h155_forged
# [5/250] Processed: p205_forged
# [6/250] Processed: f111_forged
# [7/250] Processed: h132_forged
# [8/250] Processed: h080_forged
# [9/250] Processed: c152_forged
# [10/250] Processed: s050_forged
# [11/250] Processed: h009_forged
# [12/250] Processed: e190_forged
# [13/250] Processed: c083_forged
# [14/250] Processed: o016_forged
# [15/250] Processed: s121_forged
# [16/250] Processed: cl181_forged
# [17/250] Processed: e222_forged
# [18/250] Processed: cl080_forged
# [19/250] Processed: c009_forged
# [20/250] Processed: e052_forged
# [21/250] Processed: s173_forged
# [22/250] Processed: cl216_forged
# [23/250] Processed: h139_forged
# [24/250] Processed: r080_forged
# [25/250] Processed: p027_forged
# [26/250] Processed: c104_forged
# [27/250] Processed: s216_forged
# [28/250] Processed: o190_forged
# ...

# %% [markdown]
# ***Reverb + Bandpass Filtering***

# %%
audio_folder = "/content/drive/MyDrive/forged_tracks/reverb_bandpass_filtering_forged_tracks"
image_output_folder = "/content/drive/MyDrive/STFT_Spectrograms/forged/images"
npy_output_folder = "/content/drive/MyDrive/STFT_Spectrograms/forged/npy_files"
sr = 16000
hop_length = 512
n_fft = 1024

process_audio_to_spectrograms(audio_folder, image_output_folder, npy_output_folder, sr, n_fft, hop_length)
# Out:
# Found 250 WAV files to process...
# [1/250] Processed: p225_forged
# [2/250] Processed: cl143_forged
# [3/250] Processed: f225_forged
# [4/250] Processed: r034_forged
# [5/250] Processed: e172_forged
# [6/250] Processed: o210_forged
# [7/250] Processed: j021_forged
# [8/250] Processed: f191_forged
# [9/250] Processed: p084_forged
# [10/250] Processed: cl146_forged
# [11/250] Processed: f035_forged
# [12/250] Processed: h214_forged
# [13/250] Processed: o157_forged
# [14/250] Processed: j113_forged
# [15/250] Processed: h174_forged
# [16/250] Processed: h166_forged
# [17/250] Processed: p134_forged
# [18/250] Processed: s130_forged
# [19/250] Processed: c086_forged
# [20/250] Processed: h086_forged
# [21/250] Processed: r018_forged
# [22/250] Processed: o238_forged
# [23/250] Processed: c174_forged
# [24/250] Processed: h113_forged
# [25/250] Processed: p118_forged
# [26/250] Processed: cl223_forged
# [27/250] Processed: p188_forged
# [28/250] Processed: o019_forged
# ...

# %% [markdown]
# ***Time Stretch + Reverb***

# %%
audio_folder = "/content/drive/MyDrive/forged_tracks/time_stretch_reverb_forged_tracks"
image_output_folder = "/content/drive/MyDrive/STFT_Spectrograms/forged/images"
npy_output_folder = "/content/drive/MyDrive/STFT_Spectrograms/forged/npy_files"
sr = 16000
hop_length = 512
n_fft = 1024

process_audio_to_spectrograms(audio_folder, image_output_folder, npy_output_folder, sr, n_fft, hop_length)
# Out:
# Found 250 WAV files to process...
# [1/250] Processed: c093_forged
# [2/250] Processed: cl040_forged
# [3/250] Processed: p247_forged
# [4/250] Processed: j186_forged
# [5/250] Processed: h096_forged
# [6/250] Processed: c182_forged
# [7/250] Processed: j148_forged
# [8/250] Processed: e063_forged
# [9/250] Processed: h182_forged
# [10/250] Processed: f137_forged
# [11/250] Processed: h053_forged
# [12/250] Processed: cl114_forged
# [13/250] Processed: cl192_forged
# [14/250] Processed: p025_forged
# [15/250] Processed: f198_forged
# [16/250] Processed: e097_forged
# [17/250] Processed: e209_forged
# [18/250] Processed: f060_forged
# [19/250] Processed: h037_forged
# [20/250] Processed: p233_forged
# [21/250] Processed: r093_forged
# [22/250] Processed: cl093_forged
# [23/250] Processed: e067_forged
# [24/250] Processed: j192_forged
# [25/250] Processed: r141_forged
# [26/250] Processed: o185_forged
# [27/250] Processed: o198_forged
# [28/250] Processed: f073_forged
# ...

# %% [markdown]
# ***No Transformation***

# %%
audio_folder = "/content/drive/MyDrive/forged_tracks/no_transformation_forged_tracks"
image_output_folder = "/content/drive/MyDrive/STFT_Spectrograms/forged/images"
npy_output_folder = "/content/drive/MyDrive/STFT_Spectrograms/forged/npy_files"
sr = 16000
hop_length = 512
n_fft = 1024

process_audio_to_spectrograms(audio_folder, image_output_folder, npy_output_folder, sr, n_fft, hop_length)
# Out:
# Found 250 WAV files to process...
# [1/250] Processed: cl133_forged
# [2/250] Processed: s108_forged
# [3/250] Processed: c208_forged
# [4/250] Processed: o081_forged
# [5/250] Processed: e242_forged
# [6/250] Processed: s193_forged
# [7/250] Processed: p240_forged
# [8/250] Processed: r136_forged
# [9/250] Processed: c218_forged
# [10/250] Processed: cl250_forged
# [11/250] Processed: j140_forged
# [12/250] Processed: j193_forged
# [13/250] Processed: e164_forged
# [14/250] Processed: r028_forged
# [15/250] Processed: cl138_forged
# [16/250] Processed: c108_forged
# [17/250] Processed: s120_forged
# [18/250] Processed: c140_forged
# [19/250] Processed: e107_forged
# [20/250] Processed: j208_forged
# [21/250] Processed: j158_forged
# [22/250] Processed: r163_forged
# [23/250] Processed: e162_forged
# [24/250] Processed: r003_forged
# [25/250] Processed: j112_forged
# [26/250] Processed: o024_forged
# [27/250] Processed: p042_forged
# [28/250] Processed: r218_forged
# ...

# %% [markdown]
# # ***STFT Feature Extraction***

# %%
import os
import numpy as np
import librosa
import pandas as pd
from scipy.stats import entropy

# %%
def extract_stft_features(npy_folder, output_csv, sr, hop_length):
    """
    Extract spectral features from .npy files containing log STFT data and save to CSV.

    Parameters:
    npy_folder (str): Path to folder containing .npy files
    output_csv (str): Path to save output CSV file
    sr (int): Sample rate for feature extraction
    hop_length (int): Hop length for feature extraction

    Returns:
    pd.DataFrame: DataFrame containing extracted features
    """
    feature_list = []

    for file in os.listdir(npy_folder):
        if file.endswith(".npy"):
            file_path = os.path.join(npy_folder, file)
            base_name = os.path.splitext(file)[0]

            try:
                log_stft = np.load(file_path)
            except Exception as e:
                print(f"Failed to load {file_path}: {e}")
                continue

            try:
                amplitude = librosa.db_to_amplitude(log_stft)
                S = amplitude

                # Spectral features
                spectral_centroid = np.mean(librosa.feature.spectral_centroid(S=S, sr=sr, hop_length=hop_length))
                spectral_bandwidth = np.mean(librosa.feature.spectral_bandwidth(S=S, sr=sr, hop_length=hop_length))
                spectral_rolloff = np.mean(librosa.feature.spectral_rolloff(S=S, sr=sr, hop_length=hop_length))
                spectral_flatness = np.mean(librosa.feature.spectral_flatness(S=S))

                # RMS Energy
                rms_energy = np.mean(np.sqrt(np.mean(S**2, axis=0)))

                # Energy Entropy
                norm_energy = S**2 / np.sum(S**2, axis=0, keepdims=True)
                frame_entropy = entropy(norm_energy + 1e-10, base=2, axis=0)
                entropy_val = np.mean(frame_entropy)

                # Statistical features
                mean_spectral = np.mean(log_stft)
                std_spectral = np.std(log_stft)

                # Chroma feature
                try:
                    chroma = librosa.feature.chroma_cqt(C=S, sr=sr)
                    chroma_mean = np.mean(chroma, axis=1)
                    chrome_summary = np.mean(chroma_mean)
                except Exception as e:
                    print(f"Chroma extraction failed for {base_name}: {e}")
                    chrome_summary = 0.0

                # Class label
                label = 1 if "forged" in base_name.lower() else 0

                # Genre
                genre = get_genre_from_filename(base_name)

                # Build feature dictionary
                feature_dict = {
                    "file_name": base_name,
                    "genre": genre,
                    "spectral_centroid": spectral_centroid,
                    "spectral_bandwidth": spectral_bandwidth,
                    "spectral_rolloff": spectral_rolloff,
                    "spectral_flatness": spectral_flatness,
                    "rms_energy": rms_energy,
                    "energy_entropy": entropy_val,
                    "mean": mean_spectral,
                    "std_dev": std_spectral,
                    "chroma": chrome_summary,
                    "class": label
                }

                feature_list.append(feature_dict)
                print(f"Processed {base_name}")

            except Exception as e:
                print(f"Feature extraction failed for {base_name}: {e}")

    df = pd.DataFrame(feature_list)
    df.to_csv(output_csv, index=False)
    print(f"\nFeatures saved to: {output_csv}")

    return df

# %% [markdown]
# ***STFT Feature Extraction for Original Tracks***

# %%
import os

path = '/content/drive/MyDrive/STFT_Spectrograms/original/npy_files'
print("Exists:", os.path.exists(path))
# Out:
# Exists: True

# %%
def get_genre_from_filename(filename):
    genre_map = {
        "cl": "classical",
        "c": "country",
        "e": "electronic",
        "f": "folk",
        "h": "hip hop",
        "j": "jazz",
        "o": "old historic",
        "p": "pop",
        "r": "rock",
        "s": "soul RnB",
    }
    # Split by "."
    parts = filename.split(".")
    if parts:
        # Extract alphabetic characters from the first part
        prefix = "".join(filter(str.isalpha, parts[0]))
        if prefix in genre_map:
            return genre_map[prefix]
    return None

npy_folder = "/content/drive/MyDrive/CQT_Spectrograms/original/npy_files"
output_csv = "/content/drive/MyDrive/STFT_Features/original_tracks_stft_features.csv"
sr = 16000  # Sample rate
hop_length = 512  # Hop length

df = extract_stft_features(npy_folder, output_csv, sr, hop_length)
# Out:
# Processed o201
# Processed o202
# Processed o203
# Processed o204
# Processed o205
# Processed o206
# Processed o207
# Processed o208
# Processed o209
# Processed o210
# Processed o211
# Processed o212
# Processed o213
# Processed o214
# Processed o215
# Processed o216
# Processed o217
# Processed o218
# Processed o219
# Processed o220
# Processed o221
# Processed o222
# Processed o223
# Processed o224
# Processed o225
# Processed o226
# Processed o227
# Processed o228
# Processed o229
# Processed o230
# Processed o231
# Processed o232
# Processed o233
# Processed o234
# Processed o235
# Processed o236
# Processed o237
# Processed o238
# Processed o239
# Processed o240
# Processed o241
# Processed o242
# Processed o243
# Processed o244
# Processed o245
# Processed o246
# Processed o247
# Processed o248
# Processed o249
# Processed o250
# Processed o002
# Processed o001
# Processed o003
# Processed o004
# Processed o005
# Processed o006
# Processed o007
# Processed o008
# ...

# %% [markdown]
# ***STFT Feature Extraction for Forged Tracks***

# %%
def get_genre_from_filename(filename):
    genre_map = {
        "cl": "classical",
        "c": "country",
        "e": "electronic",
        "f": "folk",
        "h": "hip hop",
        "j": "jazz",
        "o": "old historic",
        "p": "pop",
        "r": "rock",
        "s": "soul RnB",
    }
    # First split by "."
    parts = filename.split(".")
    if parts:
        # Take the first part and split by "_"
        sub_parts = parts[0].split("_")
        if sub_parts:
            prefix = "".join(filter(str.isalpha, sub_parts[0]))
            if prefix in genre_map:
                return genre_map[prefix]
    return None

npy_folder = "/content/drive/MyDrive/STFT_Spectrograms/forged/npy_files"
output_csv = "/content/drive/MyDrive/STFT_Features/forged_tracks_stft_features.csv"
sr = 16000  # Sample rate
hop_length = 512  # Hop length

df = extract_stft_features(npy_folder, output_csv, sr, hop_length)
# Out:
# Processed s089_forged
# Processed cl229_forged
# Processed f138_forged
# Processed e091_forged
# Processed r075_forged
# Processed h081_forged
# Processed h105_forged
# Processed o112_forged
# Processed e236_forged
# Processed o126_forged
# Processed s072_forged
# Processed j229_forged
# Processed r226_forged
# Processed cl240_forged
# Processed e163_forged
# Processed cl072_forged
# Processed c007_forged
# Processed r002_forged
# Processed h075_forged
# Processed f218_forged
# Processed cl089_forged
# Processed e208_forged
# Processed o133_forged
# Processed o163_forged
# Processed o078_forged
# Processed f133_forged
# Processed cl081_forged
# Processed cl042_forged
# Processed j071_forged
# Processed s199_forged
# Processed p091_forged
# Processed cl006_forged
# Processed h042_forged
# Processed o074_forged
# Processed r007_forged
# Processed f087_forged
# Processed o087_forged
# Processed e078_forged
# Processed r242_forged
# Processed f028_forged
# Processed c005_forged
# ...

# %% [markdown]
# ***Combine original and forged features' CSVs***

# %%
import pandas as pd


df1 = pd.read_csv('/content/drive/MyDrive/STFT_Features/original_tracks_stft_features.csv')
df2 = pd.read_csv('/content/drive/MyDrive/STFT_Features/forged_tracks_stft_features.csv')


merged_df = pd.concat([df1, df2], ignore_index=True)

merged_df.to_csv('/content/drive/MyDrive/STFT_Features/all_tracks_stft_features.csv', index=False)

print("Saved as 'all_tracks_stft_features.csv'.")
# Out:
# Saved as 'all_tracks_stft_features.csv'.

# %% [markdown]
# ***MinMax Scaling***

# %%
import os
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

# Define the directory in Google Drive where your files will be located
drive_path = '/content/drive/MyDrive/STFT_Features'  # Adjust this path if needed

def split_and_scale_csv(input_csv_file, output_csv_prefix="stft_scaled_output"):
    """
    Splits a CSV file into two CSV files based on the 'class' column (0 or 1),
    shuffles the data, and then applies Min-Max scaling to the numerical
    columns of each resulting CSV separately. Reads from and writes to Google Drive.

    Args:
        input_csv_file (str): Name of the input CSV file in Google Drive.
        output_csv_prefix (str): Prefix for the output CSV file names in Google Drive.
                                   The output files will be named as
                                   f"{output_csv_prefix}_class_0.csv" and
                                   f"{output_csv_prefix}_class_1.csv".
    """
    input_file_path = os.path.join(drive_path, input_csv_file)

    try:
        # Read the CSV file into a pandas DataFrame from Google Drive
        df = pd.read_csv(input_file_path)

        # Check if the 'class' column exists
        if 'class' not in df.columns:
            print(f"Error: 'class' column not found in the input CSV file: {input_csv_file}")
            return

        # Shuffle the DataFrame
        df_shuffled = df.sample(frac=1, random_state=42).reset_index(drop=True)

        # Separate the DataFrame based on the 'class' column
        df_class_0 = df_shuffled[df_shuffled['class'] == 0].copy()
        df_class_1 = df_shuffled[df_shuffled['class'] == 1].copy()

        # Identify numerical columns (excluding the 'class' column)
        numerical_cols_0 = df_class_0.select_dtypes(include=['number']).columns.tolist()
        if 'class' in numerical_cols_0:
            numerical_cols_0.remove('class')

        numerical_cols_1 = df_class_1.select_dtypes(include=['number']).columns.tolist()
        if 'class' in numerical_cols_1:
            numerical_cols_1.remove('class')

        # Apply Min-Max scaling to class 0 data
        if numerical_cols_0:
            scaler_0 = MinMaxScaler()
            df_class_0[numerical_cols_0] = scaler_0.fit_transform(df_class_0[numerical_cols_0])
            print(f"Min-Max scaling applied to numerical columns of class 0.")
        else:
            print("No numerical columns found (excluding 'class') for class 0 to scale.")

        # Apply Min-Max scaling to class 1 data
        if numerical_cols_1:
            scaler_1 = MinMaxScaler()
            df_class_1[numerical_cols_1] = scaler_1.fit_transform(df_class_1[numerical_cols_1])
            print(f"Min-Max scaling applied to numerical columns of class 1.")
        else:
            print("No numerical columns found (excluding 'class') for class 1 to scale.")

        # Define output file paths in Google Drive
        output_file_path_0 = os.path.join(drive_path, f"{output_csv_prefix}_class_0.csv")
        output_file_path_1 = os.path.join(drive_path, f"{output_csv_prefix}_class_1.csv")

        # Save the scaled DataFrames to new CSV files in Google Drive
        df_class_0.to_csv(output_file_path_0, index=False)
        df_class_1.to_csv(output_file_path_1, index=False)

        print(f"\nSuccessfully split and scaled '{input_csv_file}' into:")
        print(f"- '{output_csv_prefix}_class_0.csv' (containing scaled rows with class 0 in Google Drive)")
        print(f"- '{output_csv_prefix}_class_1.csv' (containing scaled rows with class 1 in Google Drive)")

    except FileNotFoundError:
        print(f"Error: Input file '{input_csv_file}' not found in Google Drive at '{drive_path}'.")
    except Exception as e:
        print(f"An error occurred: {e}")

if __name__ == "__main__":
    # Example usage: Replace 'your_input_file.csv' with the actual name
    # of your CSV file in your Google Drive root directory (or adjust drive_path).
    input_file = "all_tracks_stft_features.csv"
    split_and_scale_csv(input_file)
# Out:
# Min-Max scaling applied to numerical columns of class 0.
# Min-Max scaling applied to numerical columns of class 1.
#
# Successfully split and scaled 'all_tracks_stft_features.csv' into:
# - 'stft_scaled_output_class_0.csv' (containing scaled rows with class 0 in Google Drive)
# - 'stft_scaled_output_class_1.csv' (containing scaled rows with class 1 in Google Drive)

# %% [markdown]
# ***Split by genre***

# %%
import pandas as pd
import os
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')

# Define the directory in Google Drive where your files are located
drive_path = '/content/drive/MyDrive/STFT_Features'  # Adjust this path if needed

genres = ['classical', 'country', 'electronic', 'folk', 'hip hop', 'jazz', 'old historic', 'pop', 'rock', 'soul RnB']

def split_by_genre(input_csv_file):
    '''Splits a CSV file by genre and saves each genre to a separate CSV file in Google Drive.'''
    input_file_path = os.path.join(drive_path, input_csv_file)

    try:
        df = pd.read_csv(input_file_path)

        if 'genre' not in df.columns:
            print(f"Error: 'genre' column not found in {input_csv_file}")
            return

        for genre in genres:
            genre_df = df[df['genre'] == genre]
            if not genre_df.empty:  # Only save if there are rows for this genre
                output_file_name = f"{os.path.splitext(input_csv_file)[0]}_{genre.replace(' ', '_')}.csv" # Replace spaces in genre name with underscores
                output_file_path = os.path.join(drive_path, output_file_name)
                genre_df.to_csv(output_file_path, index=False)
                print(f"Saved {genre} data to {output_file_name}")
            else:
                print(f"No data found for genre '{genre}' in {input_csv_file}")

    except FileNotFoundError:
        print(f"Error: Input file '{input_csv_file}' not found in Google Drive at '{drive_path}'.")
    except Exception as e:
        print(f"An error occurred: {e}")

if __name__ == "__main__":
    # Example usage:  Make sure 'class_0.csv' and 'class_1.csv' are in your Google Drive root (or adjust drive_path)
    split_by_genre('stft_scaled_output_class_0.csv')
    split_by_genre('stft_scaled_output_class_1.csv')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Saved classical data to stft_scaled_output_class_0_classical.csv
# Saved country data to stft_scaled_output_class_0_country.csv
# Saved electronic data to stft_scaled_output_class_0_electronic.csv
# Saved folk data to stft_scaled_output_class_0_folk.csv
# Saved hip hop data to stft_scaled_output_class_0_hip_hop.csv
# Saved jazz data to stft_scaled_output_class_0_jazz.csv
# Saved old historic data to stft_scaled_output_class_0_old_historic.csv
# Saved pop data to stft_scaled_output_class_0_pop.csv
# Saved rock data to stft_scaled_output_class_0_rock.csv
# Saved soul RnB data to stft_scaled_output_class_0_soul_RnB.csv
# Saved classical data to stft_scaled_output_class_1_classical.csv
# Saved country data to stft_scaled_output_class_1_country.csv
# Saved electronic data to stft_scaled_output_class_1_electronic.csv
# ...

# %% [markdown]
# ***Train/Val/Test Split***

# %%
import pandas as pd
import os
from sklearn.model_selection import train_test_split
from google.colab import drive
import numpy as np

# Mount Google Drive
drive.mount('/content/drive')

# Define the directory in Google Drive
drive_path = '/content/drive/MyDrive/STFT_Features'  # Adjust if needed

def split_data_with_distribution_control(input_files, drive_path, test_size=0.15, val_size=0.15, random_state=42):
    """
    Splits multiple CSV files (assumed to represent different classes and genres) into training,
    validation, and test sets, ensuring that the class and genre distributions are maintained
    across the resulting sets. Each input CSV is assumed to have 250 rows.

    Args:
        input_files (list): List of input CSV file names in Google Drive.
        drive_path (str): Path to the directory in Google Drive.
        test_size (float): Proportion of the data for the test set.
        val_size (float): Proportion of the data for the validation set.
        random_state (int): Controls data shuffling for reproducibility.
    """
    # Load all dataframes
    dfs = []
    for file in input_files:
        file_path = os.path.join(drive_path, file)
        try:
            df = pd.read_csv(file_path)
            if len(df) != 250:
                print(f"Error: {file} does not have 250 rows. Skipping.")
                return
            dfs.append(df)
        except FileNotFoundError:
            print(f"Error: File not found: {file_path}")
            return

    # Combine all dataframes
    combined_df = pd.concat(dfs, ignore_index=True)

    # Create empty dataframes for the splits
    train_df = pd.DataFrame()
    val_df = pd.DataFrame()
    test_df = pd.DataFrame()

    # Get unique classes and genres
    classes = combined_df['class'].unique()
    genres = combined_df['genre'].unique()

    for cls in classes:
        for genre in genres:
            # Get the data for the current class and genre
            subset_df = combined_df[(combined_df['class'] == cls) & (combined_df['genre'] == genre)]
            if subset_df.empty:
                continue  # Skip if no data for this combination

            # Split the subset into train, val, and test sets
            train_subset, temp_subset = train_test_split(subset_df, test_size=(test_size + val_size), random_state=random_state)
            val_subset, test_subset = train_test_split(temp_subset, test_size=test_size / (test_size + val_size), random_state=random_state)

            # Add the split subsets to the main dataframes
            train_df = pd.concat([train_df, train_subset], ignore_index=True)
            val_df = pd.concat([val_df, val_subset], ignore_index=True)
            test_df = pd.concat([test_df, test_subset], ignore_index=True)

    # Save the dataframes to CSV files
    train_file_path = os.path.join(drive_path, 'stft_train_set.csv')
    val_file_path = os.path.join(drive_path, 'stft_val_set.csv')
    test_file_path = os.path.join(drive_path, 'stft_test_set.csv')

    train_df.to_csv(train_file_path, index=False)
    val_df.to_csv(val_file_path, index=False)
    test_df.to_csv(test_file_path, index=False)

    print(f"Saved combined train, val, and test sets to:\n{train_file_path}\n{val_file_path}\n{test_file_path}")

if __name__ == "__main__":
    # Example Usage
    input_files = [
        'stft_scaled_output_class_0_classical.csv', 'stft_scaled_output_class_0_country.csv', 'stft_scaled_output_class_0_electronic.csv', 'stft_scaled_output_class_0_folk.csv',
        'stft_scaled_output_class_0_hip_hop.csv', 'stft_scaled_output_class_0_jazz.csv', 'stft_scaled_output_class_0_old_historic.csv', 'stft_scaled_output_class_0_pop.csv',
        'stft_scaled_output_class_0_rock.csv', 'stft_scaled_output_class_0_soul_RnB.csv',
        'stft_scaled_output_class_1_classical.csv', 'stft_scaled_output_class_1_country.csv', 'stft_scaled_output_class_1_electronic.csv', 'stft_scaled_output_class_1_folk.csv',
        'stft_scaled_output_class_1_hip_hop.csv', 'stft_scaled_output_class_1_jazz.csv', 'stft_scaled_output_class_1_old_historic.csv', 'stft_scaled_output_class_1_pop.csv',
        'stft_scaled_output_class_1_rock.csv', 'stft_scaled_output_class_1_soul_RnB.csv'
    ]

    split_data_with_distribution_control(input_files, drive_path)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Saved combined train, val, and test sets to:
# /content/drive/MyDrive/STFT_Features/stft_train_set.csv
# /content/drive/MyDrive/STFT_Features/stft_val_set.csv
# /content/drive/MyDrive/STFT_Features/stft_test_set.csv

# %% [markdown]
# ***Distribution in Train/Val/Test***

# %%
import pandas as pd
import os
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')

# Define the directory in Google Drive where your files are located
drive_path = '/content/drive/MyDrive/STFT_Features'  # Adjust this path if needed

def print_record_counts(csv_file, drive_path):
    file_path = os.path.join(drive_path, csv_file)

    try:
        # Read the CSV file into a pandas DataFrame from Google Drive
        df = pd.read_csv(file_path)

        # Print the total number of records
        total_records = len(df)
        print(f"\nFile: {csv_file}")
        print(f"Total Records: {total_records}")

        # Print the number of records for each class and genre combination
        print("\nRecords per Class and Genre Combination:")
        combined_counts = df.groupby(['class', 'genre']).size()
        for (cls, genre), count in combined_counts.items():
            print(f"- Class {cls}, Genre {genre}: {count}")

    except FileNotFoundError:
        print(f"Error: File not found: {file_path}")
    except KeyError as e:
        print(f"Error: Required column not found in CSV file: {csv_file}.  Missing column: {e}")
    except Exception as e:
        print(f"An error occurred: {e}")

if __name__ == "__main__":
    # Example usage: Specify the names of your train, validation, and test CSV files.
    csv_files = ['stft_train_set.csv', 'stft_val_set.csv', 'stft_test_set.csv']  # Adjust these names if needed

    for csv_file in csv_files:
        print_record_counts(csv_file, drive_path)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#
# File: stft_train_set.csv
# Total Records: 3500
#
# Records per Class and Genre Combination:
# - Class 0, Genre classical: 175
# - Class 0, Genre country: 175
# - Class 0, Genre electronic: 175
# - Class 0, Genre folk: 175
# - Class 0, Genre hip hop: 175
# - Class 0, Genre jazz: 175
# - Class 0, Genre old historic: 175
# - Class 0, Genre pop: 175
# - Class 0, Genre rock: 175
# - Class 0, Genre soul RnB: 175
# - Class 1, Genre classical: 175
# - Class 1, Genre country: 175
# - Class 1, Genre electronic: 175
# - Class 1, Genre folk: 175
# - Class 1, Genre hip hop: 175
# - Class 1, Genre jazz: 175
# - Class 1, Genre old historic: 175
# - Class 1, Genre pop: 175
# - Class 1, Genre rock: 175
# - Class 1, Genre soul RnB: 175
#
# File: stft_val_set.csv
# Total Records: 740
#
# Records per Class and Genre Combination:
# - Class 0, Genre classical: 37
# ...

# %% [markdown]
# # ***Xception Model Training and Evaluation***

# %%
train_path = '/content/drive/MyDrive/MyProject/stft_train_70.csv'
val_path = '/content/drive/MyDrive/MyProject/stft_val_15.csv'
test_path = '/content/drive/MyDrive/MyProject/stft_test_15.csv'

# %% [markdown]
# ***With Gaussian Noise***

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.layers import Input, Dense, Dropout, Conv1D, SeparableConv1D, BatchNormalization, Activation, MaxPooling1D, Add, Flatten
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import regularizers
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from sklearn.metrics import precision_score, recall_score, f1_score, roc_auc_score, confusion_matrix, roc_curve, auc
from datetime import datetime
import os
import matplotlib.pyplot as plt
from sklearn.metrics import ConfusionMatrixDisplay

def add_gaussian_noise(features, mean=0.0, std=0.02):

    noise = np.random.normal(mean, std, features.shape)
    noisy_features = features + noise
    noisy_features = np.clip(noisy_features, 0.0, 1.0)
    return noisy_features

def custom_generator(X, y, batch_size, apply_noise=True):
    while True:
        indices = np.random.permutation(len(X))
        for i in range(0, len(X), batch_size):
            batch_indices = indices[i:i + batch_size]
            batch_X = X[batch_indices]
            batch_y = y[batch_indices]
            if apply_noise:
                batch_X = add_gaussian_noise(batch_X, mean=0.0, std=0.01)
            yield batch_X, batch_y

try:
    train_data = pd.read_csv(train_path)
    val_data = pd.read_csv(val_path)
    test_data = pd.read_csv(test_path)
except FileNotFoundError:
    print("Error: CSV files not found. Please check the paths.")
    raise

feature_columns = [col for col in train_data.columns if col != 'class']

print("Train Data Shape:", train_data.shape)
print("Validation Data Shape:", val_data.shape)
print("Test Data Shape:", test_data.shape)
print("Train Class Distribution:", train_data['class'].value_counts(normalize=True))
print("Validation Class Distribution:", val_data['class'].value_counts(normalize=True))
print("Test Class Distribution:", test_data['class'].value_counts(normalize=True))

train_data = train_data.sample(frac=1, random_state=42).reset_index(drop=True)
all_features = [col for col in train_data.columns if col != 'class']

X_train = train_data[all_features].values
y_train = train_data['class'].values
X_val = val_data[all_features].values
y_val = val_data['class'].values
X_test = test_data[all_features].values
y_test = test_data['class'].values

X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_val = X_val.reshape(X_val.shape[0], X_val.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

class_weights = {0: 1.0 / np.mean(y_train == 0), 1: 1.0 / np.mean(y_train == 1)}
print("Class Weights:", class_weights)

def entry_flow(x):
    x = Conv1D(32, 3, strides=2, padding='same', use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = SeparableConv1D(64, 3, padding='same', use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling1D(2, strides=2, padding='same')(x)
    residual = Conv1D(128, 1, strides=2, padding='same', use_bias=False)(x)
    x = Activation('relu')(x)
    x = SeparableConv1D(128, 3, padding='same', use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = SeparableConv1D(128, 3, padding='same', use_bias=False)(x)
    x = BatchNormalization()(x)
    x = MaxPooling1D(2, strides=2, padding='same')(x)
    x = Add()([x, residual])
    residual = Conv1D(256, 1, strides=2, padding='same', use_bias=False)(x)
    x = Activation('relu')(x)
    x = SeparableConv1D(256, 3, padding='same', use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = SeparableConv1D(256, 3, padding='same', use_bias=False)(x)
    x = BatchNormalization()(x)
    x = MaxPooling1D(2, strides=2, padding='same')(x)
    x = Add()([x, residual])
    return x

def middle_flow(x, num_blocks=2):
    for _ in range(num_blocks):
        residual = x
        x = Activation('relu')(x)
        x = SeparableConv1D(256, 3, padding='same', use_bias=False)(x)
        x = BatchNormalization()(x)
        x = Activation('relu')(x)
        x = SeparableConv1D(256, 3, padding='same', use_bias=False)(x)
        x = BatchNormalization()(x)
        x = Activation('relu')(x)
        x = SeparableConv1D(256, 3, padding='same', use_bias=False)(x)
        x = BatchNormalization()(x)
        x = Add()([x, residual])
    return x

def exit_flow(x):
    residual = Conv1D(512, 1, strides=2, padding='same', use_bias=False)(x)
    x = Activation('relu')(x)
    x = SeparableConv1D(512, 3, padding='same', use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = SeparableConv1D(512, 3, padding='same', use_bias=False)(x)
    x = BatchNormalization()(x)
    x = MaxPooling1D(2, strides=2, padding='same')(x)
    x = Add()([x, residual])
    x = SeparableConv1D(728, 3, padding='same', use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = SeparableConv1D(1024, 3, padding='same', use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling1D(2, strides=2, padding='same')(x)
    return x

initial_lr = 0.0005
batch_size = 32
max_epochs = 250
patience = 15
dropout_rate = 0.5
num_dropouts = 3
kernel_regularizer = regularizers.l2(0.01)
middle_flow_blocks = 2

inputs = Input(shape=(len(all_features), 1))
x = entry_flow(inputs)
x = middle_flow(x, num_blocks=middle_flow_blocks)
x = exit_flow(x)
x = Flatten()(x)
x = Dense(128, activation='relu', kernel_regularizer=kernel_regularizer)(x)
x = Dropout(dropout_rate)(x)
x = Dense(64, activation='relu', kernel_regularizer=kernel_regularizer)(x)
x = Dropout(dropout_rate)(x)
x = Dense(32, activation='relu', kernel_regularizer=kernel_regularizer)(x)  # Added for 3rd dropout
x = Dropout(dropout_rate)(x)
outputs = Dense(1, activation='sigmoid')(x)

model = Model(inputs, outputs)

model.compile(optimizer=Adam(learning_rate=initial_lr),
              loss=tf.keras.losses.BinaryCrossentropy(label_smoothing=0.1),
              metrics=['accuracy'])

early_stopping = EarlyStopping(monitor='val_loss', patience=patience, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=0.00001, verbose=1)

train_generator = custom_generator(X_train, y_train, batch_size, apply_noise=True)
history = model.fit(
    train_generator,
    steps_per_epoch=len(X_train) // batch_size,
    validation_data=(X_val, y_val),
    epochs=max_epochs,
    callbacks=[early_stopping, reduce_lr],
    verbose=2
)

# Evaluate model
val_loss, val_acc = model.evaluate(X_val, y_val, verbose=0)

y_pred = (model.predict(X_test) > 0.5).astype(int)
y_pred_proba = model.predict(X_test)

# Calculate metrics (unchanged)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
roc_auc = roc_auc_score(y_test, y_pred_proba)

print("\nFinal Xception Results:")
print(f"Validation Accuracy: {val_acc:.4f}")
print(f"Precision (Test): {precision:.4f}")
print(f"Recall (Test): {recall:.4f}")
print(f"F1-Score (Test): {f1:.4f}")
print(f"ROC-AUC (Test): {roc_auc:.4f}")

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Xception Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Xception Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.savefig('accuracy_loss_plot.png')

cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Class 0', 'Class 1'])
disp.plot(cmap=plt.cm.Blues)
plt.title('Confusion Matrix (Test Set)')
plt.savefig('confusion_matrix.png')

fpr, tpr, _ = roc_curve(y_test, y_pred_proba)
roc_auc = auc(fpr, tpr)
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (area = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (Test Set)')
plt.legend(loc="lower right")
plt.grid(True)
plt.savefig('roc_curve.png')
# Out:
# Train Data Shape: (2800, 10)
# Validation Data Shape: (600, 10)
# Test Data Shape: (600, 10)
# Train Class Distribution: class
# 0.0    0.5
# 1.0    0.5
# Name: proportion, dtype: float64
# Validation Class Distribution: class
# 1.0    0.5
# 0.0    0.5
# Name: proportion, dtype: float64
# Test Class Distribution: class
# 1.0    0.5
# 0.0    0.5
# Name: proportion, dtype: float64
# Class Weights: {0: np.float64(2.0), 1: np.float64(2.0)}
# Epoch 1/250
# 87/87 - 32s - 369ms/step - accuracy: 0.5381 - loss: 3.5889 - val_accuracy: 0.5000 - val_loss: 2.9132 - learning_rate: 5.0000e-04
# Epoch 2/250
# 87/87 - 11s - 126ms/step - accuracy: 0.5972 - loss: 2.4215 - val_accuracy: 0.5000 - val_loss: 2.0516 - learning_rate: 5.0000e-04
# Epoch 3/250
# 87/87 - 12s - 134ms/step - accuracy: 0.6535 - loss: 1.7197 - val_accuracy: 0.5000 - val_loss: 1.5449 - learning_rate: 5.0000e-04
# Epoch 4/250
# ...

# %%
test_loss, test_acc = model.evaluate(X_test, y_test, verbose=2)
print(f"Test Accuracy: {test_acc:.4f}")
print(f"Test Loss: {test_loss:.4f}")
# Out:
# 19/19 - 0s - 11ms/step - accuracy: 0.7533 - loss: 0.5459
# Test Accuracy: 0.7533
# Test Loss: 0.5459

# %% [markdown]
# ***Without Gaussian Noise***

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.layers import Input, Dense, Dropout, Conv1D, SeparableConv1D, BatchNormalization, Activation, MaxPooling1D, Add, Flatten
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import regularizers
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from sklearn.metrics import precision_score, recall_score, f1_score, roc_auc_score, confusion_matrix, roc_curve, auc
from datetime import datetime
import os
import matplotlib.pyplot as plt
from sklearn.metrics import ConfusionMatrixDisplay

try:
    train_data = pd.read_csv(train_path)
    val_data = pd.read_csv(val_path)
    test_data = pd.read_csv(test_path)
except FileNotFoundError:
    print("Error: CSV files not found. Please check the paths.")
    raise

feature_columns = [col for col in train_data.columns if col != 'class']

print("Train Data Shape:", train_data.shape)
print("Validation Data Shape:", val_data.shape)
print("Test Data Shape:", test_data.shape)
print("Train Class Distribution:", train_data['class'].value_counts(normalize=True))
print("Validation Class Distribution:", val_data['class'].value_counts(normalize=True))
print("Test Class Distribution:", test_data['class'].value_counts(normalize=True))

train_data = train_data.sample(frac=1, random_state=42).reset_index(drop=True)
all_features = [col for col in train_data.columns if col != 'class']

X_train = train_data[all_features].values
y_train = train_data['class'].values
X_val = val_data[all_features].values
y_val = val_data['class'].values
X_test = test_data[all_features].values
y_test = test_data['class'].values

X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_val = X_val.reshape(X_val.shape[0], X_val.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

class_weights = {0: 1.0 / np.mean(y_train == 0), 1: 1.0 / np.mean(y_train == 1)}
print("Class Weights:", class_weights)

def entry_flow(x):
    x = Conv1D(32, 3, strides=2, padding='same', use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = SeparableConv1D(64, 3, padding='same', use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling1D(2, strides=2, padding='same')(x)
    residual = Conv1D(128, 1, strides=2, padding='same', use_bias=False)(x)
    x = Activation('relu')(x)
    x = SeparableConv1D(128, 3, padding='same', use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = SeparableConv1D(128, 3, padding='same', use_bias=False)(x)
    x = BatchNormalization()(x)
    x = MaxPooling1D(2, strides=2, padding='same')(x)
    x = Add()([x, residual])
    residual = Conv1D(256, 1, strides=2, padding='same', use_bias=False)(x)
    x = Activation('relu')(x)
    x = SeparableConv1D(256, 3, padding='same', use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = SeparableConv1D(256, 3, padding='same', use_bias=False)(x)
    x = BatchNormalization()(x)
    x = MaxPooling1D(2, strides=2, padding='same')(x)
    x = Add()([x, residual])
    return x

def middle_flow(x, num_blocks=2):
    for _ in range(num_blocks):
        residual = x
        x = Activation('relu')(x)
        x = SeparableConv1D(256, 3, padding='same', use_bias=False)(x)
        x = BatchNormalization()(x)
        x = Activation('relu')(x)
        x = SeparableConv1D(256, 3, padding='same', use_bias=False)(x)
        x = BatchNormalization()(x)
        x = Activation('relu')(x)
        x = SeparableConv1D(256, 3, padding='same', use_bias=False)(x)
        x = BatchNormalization()(x)
        x = Add()([x, residual])
    return x

def exit_flow(x):
    residual = Conv1D(512, 1, strides=2, padding='same', use_bias=False)(x)
    x = Activation('relu')(x)
    x = SeparableConv1D(512, 3, padding='same', use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = SeparableConv1D(512, 3, padding='same', use_bias=False)(x)
    x = BatchNormalization()(x)
    x = MaxPooling1D(2, strides=2, padding='same')(x)
    x = Add()([x, residual])
    x = SeparableConv1D(728, 3, padding='same', use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = SeparableConv1D(1024, 3, padding='same', use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling1D(2, strides=2, padding='same')(x)
    return x

initial_lr = 0.0005
batch_size = 32
max_epochs = 250
patience = 15
dropout_rate = 0.5
kernel_regularizer = regularizers.l2(0.01)
middle_flow_blocks = 2

inputs = Input(shape=(len(all_features), 1))
x = entry_flow(inputs)
x = middle_flow(x, num_blocks=middle_flow_blocks)
x = exit_flow(x)
x = Flatten()(x)
x = Dense(128, activation='relu', kernel_regularizer=kernel_regularizer)(x)
x = Dropout(dropout_rate)(x)
x = Dense(64, activation='relu', kernel_regularizer=kernel_regularizer)(x)
x = Dropout(dropout_rate)(x)
x = Dense(32, activation='relu', kernel_regularizer=kernel_regularizer)(x)
x = Dropout(dropout_rate)(x)
outputs = Dense(1, activation='sigmoid')(x)

model = Model(inputs, outputs)

model.compile(optimizer=Adam(learning_rate=initial_lr),
              loss=tf.keras.losses.BinaryCrossentropy(label_smoothing=0.1),
              metrics=['accuracy'])

early_stopping = EarlyStopping(monitor='val_loss', patience=patience, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=0.00001, verbose=1)

history = model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=max_epochs,
    batch_size=batch_size,
    class_weight=class_weights,
    callbacks=[early_stopping, reduce_lr],
    verbose=2
)

# Evaluate model
val_loss, val_acc = model.evaluate(X_val, y_val, verbose=0)

y_pred = (model.predict(X_test) > 0.5).astype(int)
y_pred_proba = model.predict(X_test)

precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
roc_auc = roc_auc_score(y_test, y_pred_proba)

print("\nFinal Xception Results:")
print(f"Validation Accuracy: {val_acc:.4f}")
print(f"Precision (Test): {precision:.4f}")
print(f"Recall (Test): {recall:.4f}")
print(f"F1-Score (Test): {f1:.4f}")
print(f"ROC-AUC (Test): {roc_auc:.4f}")

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Xception Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Xception Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.savefig('accuracy_loss_plot.png')

cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Class 0', 'Class 1'])
disp.plot(cmap=plt.cm.Blues)
plt.title('Confusion Matrix (Test Set)')
plt.savefig('confusion_matrix.png')

fpr, tpr, _ = roc_curve(y_test, y_pred_proba)
roc_auc = auc(fpr, tpr)
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (area = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (Test Set)')
plt.legend(loc="lower right")
plt.grid(True)
plt.savefig('roc_curve.png')
# Out:
# Train Data Shape: (2800, 10)
# Validation Data Shape: (600, 10)
# Test Data Shape: (600, 10)
# Train Class Distribution: class
# 0.0    0.5
# 1.0    0.5
# Name: proportion, dtype: float64
# Validation Class Distribution: class
# 1.0    0.5
# 0.0    0.5
# Name: proportion, dtype: float64
# Test Class Distribution: class
# 1.0    0.5
# 0.0    0.5
# Name: proportion, dtype: float64
# Class Weights: {0: np.float64(2.0), 1: np.float64(2.0)}
# Epoch 1/250
# 88/88 - 30s - 343ms/step - accuracy: 0.5414 - loss: 4.3743 - val_accuracy: 0.5000 - val_loss: 3.1430 - learning_rate: 5.0000e-04
# Epoch 2/250
# 88/88 - 19s - 210ms/step - accuracy: 0.6104 - loss: 3.3872 - val_accuracy: 0.5000 - val_loss: 2.4099 - learning_rate: 5.0000e-04
# Epoch 3/250
# 88/88 - 11s - 129ms/step - accuracy: 0.6639 - loss: 2.7032 - val_accuracy: 0.5000 - val_loss: 1.9064 - learning_rate: 5.0000e-04
# Epoch 4/250
# ...

# %%
test_loss, test_acc = model.evaluate(X_test, y_test, verbose=2)
print(f"Test Accuracy: {test_acc:.4f}")
print(f"Test Loss: {test_loss:.4f}")
# Out:
# 19/19 - 0s - 24ms/step - accuracy: 0.7883 - loss: 0.5461
# Test Accuracy: 0.7883
# Test Loss: 0.5461
